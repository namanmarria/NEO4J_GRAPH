# %%
import pandas as pd

# %%
pip install neo4j
# Out:
# Requirement already satisfied: neo4j in c:\users\marri\anaconda3\lib\site-packages (5.8.1)
# Requirement already satisfied: pytz in c:\users\marri\anaconda3\lib\site-packages (from neo4j) (2020.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from neo4j import GraphDatabase as gd

# %%
class abc:
    def __init__(self,uri,user,password):
        self.driver=gd.driver(uri,auth=(user,password))
    
    def close(self):
        self.driver.close()
        
    def print_greeting(self,message):
        with self.driver.session() as session:
            greeting = session.execute_write(self._create_and_return_greeting, message)
            print(greeting)
    
    @staticmethod
    def _create_and_return_greeting(tx,message):
        result =tx.run("CREATE (a:Greeting) " 
                      "SET a.message =$message "
                       "RETURN a.message + ', from node ' + id(a)",message=message)
        
        return result.single()[0]


if __name__ =='__main__':
    greeter=abc("bolt://localhost:7687","neo4j","admin123")
    greeter.print_greeting("Hello World")
    greeter.close()
# Out:
# Hello World, from node 0

# %%
#create neo4j graph using from a csv file

# %%
driver=gd.driver(uri="bolt://localhost:7687",auth=("neo4j","admin123"))

# %%
driver

# %%
session=driver.session()

# %%
df=pd.read_csv('stations.csv')

# %%
df
# Out:
#                                    URL  OBJECTID                         NAME  \
# 0    http://web.mta.info/nyct/service/         1                     Astor Pl
# 1    http://web.mta.info/nyct/service/         2                     Canal St
# 2    http://web.mta.info/nyct/service/         3                      50th St
# 3    http://web.mta.info/nyct/service/         4                    Bergen St
# 4    http://web.mta.info/nyct/service/         5             Pennsylvania Ave
# ..                                 ...       ...                          ...
# 468  http://web.mta.info/nyct/service/       469  Coney Island - Stillwell Av
# 469  http://web.mta.info/nyct/service/       470       34th St - Hudson Yards
# 470  http://web.mta.info/nyct/service/       641                      72nd St
# 471  http://web.mta.info/nyct/service/       642                      86th St
# 472  http://web.mta.info/nyct/service/       643                      96th St
#
#                                          the_geom           LINE  \
# 0    POINT (-73.99106999861966 40.73005400028978)  4-6-6 Express
# 1    POINT (-74.00019299927328 40.71880300107709)  4-6-6 Express
# 2    POINT (-73.98384899986625 40.76172799961419)            1-2
# 3    POINT (-73.97499915116808 40.68086213682956)          2-3-4
# 4    POINT (-73.89488591154061 40.66471445143568)            3-4
# ..                                            ...            ...
# 468   POINT (-73.9812359981396 40.57728100006751)        D-F-N-Q
# 469  POINT (-74.00219709442206 40.75544635961596)    7-7 Express
# 470  POINT (-73.95836178682246 40.76880251014895)              Q
# 471  POINT (-73.95177090964917 40.77786104333163)              Q
# 472  POINT (-73.9470660219183 40.784236650177654)              Q
#
#                                                  NOTES
# 0    4 nights, 6-all times, 6 Express-weekdays AM s...
# 1    4 nights, 6-all times, 6 Express-weekdays AM s...
# 2                                1-all times, 2-nights
# 3             4-nights, 3-all other times, 2-all times
# 4                          4-nights, 3-all other times
# ..                                                 ...
# 468                                  D,F,N,Q-all times
# 469  7-all times, 7 Express-rush hours AM westbound...
# 470                                        Q-all times
# 471                                        Q-all times
# 472                                        Q-all times
#
# [473 rows x 6 columns]

# %%
#get distinct trains
trains=df['LINE'].unique()

# %%
(trains)
# Out:
# array(['4-6-6 Express', '1-2', '2-3-4', '3-4', '1', 'A-B-C', 'A-C',
#        'E-M-R', 'J-M-Z', 'J-Z', 'B-D-N-Q-R', 'A-S', '2-5', 'B-D',
#        '7-7 Express', '6-6 Express', '4-5-6-6 Express', 'D-N-R',
#        '2-3-4-5', '4', '6', 'A', 'B-D-F-M', 'B-Q-S', 'D', 'E', 'E-F',
#        'E-J-Z', 'E-M', 'F', 'G', 'L', 'J', 'J-M', 'N', 'N-W', 'N-Q-R-W',
#        'S', 'Q', '7-7 Express-N-W', 'F-G', 'B-Q', 'D-N-Q-R', '4-5', '5',
#        '1-2-3', '2-3', '3', '7', 'F-Q', 'A-C-E', 'M', 'E-F-M-R', '2',
#        'A-B-C-D', 'R', 'B-D-E', 'N-R-W', 'F-M', 'A-C-G', 'A-C-F', 'N-R',
#        'R-W', 'N-Q', 'A-C-S', 'D-F-N-Q'], dtype=object)

# %% [markdown]
# ###  GRAPH IS CREATED

# %%
# don't want to duplicate LINE and NAME so need to make a constraint
#run query q1
q1='''
MERGE(A:TRAIN{train_name:$train_name})
MERGE(B:STATION{station_name:$station_name})
MERGE (A)-[:GOES_TO]->(B)
'''

for tnames in trains:
    #groupby name and line anf get names of train names
    x=df.groupby("LINE")[['NAME','LINE']].get_group(tnames)["NAME"]
    #iterating through x to find the stations
    for sname in x:
        p={'train_name':tnames,"station_name":sname}
        session.run(q1,p)

# %% [markdown]
# ###  Data analysis using neo4j graph

# %%
sns=df["NAME"].unique()

# %%
len(sns)
# Out:
# 355

# %%
q2="""
MATCH (train)-[:GOES_TO]->(station)
return train,station
"""

# %%
results=session.run(q2)

# %%
data=results.data()

# %%
data
# Out:
# [{'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': 'Astor Pl'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': 'Canal St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': '33rd St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': '96th St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': '77th St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': '51st St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': '23rd St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': '68th St - Hunter College'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': '28th St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': '110th St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': 'Bleecker St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': '103rd St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': '116th St'}},
#  {'train': {'train_name': '4-6-6 Express'},
#   'station': {'station_name': 'Spring St'}},
#  {'train': {'train_name': '1-2'}, 'station': {'station_name': '50th St'}},
#  {'train': {'train_name': '1-2'}, 'station': {'station_name': '86th St'}},
#  {'train': {'train_name': '1-2'},
#   'station': {'station_name': '66th St - Lincoln Ctr'}},
#  {'train': {'train_name': '1-2'}, 'station': {'station_name': 'Canal St'}},
#  {'train': {'train_name': '1-2'},
#   'station': {'station_name': '59th St - Columbus Circle'}},
#  {'train': {'train_name': '1-2'}, 'station': {'station_name': '23rd St'}},
#  {'train': {'train_name': '1-2'}, 'station': {'station_name': 'Houston St'}},
#  {'train': {'train_name': '1-2'}, 'station': {'station_name': '79th St'}},
#  {'train': {'train_name': '1-2'},
#   'station': {'station_name': 'Christopher St - Sheridan Sq'}},
#  {'train': {'train_name': '1-2'}, 'station': {'station_name': '28th St'}},
#  {'train': {'train_name': '1-2'}, 'station': {'station_name': '18th St'}},
#  {'train': {'train_name': '1-2'}, 'station': {'station_name': 'Franklin St'}},
#  {'train': {'train_name': '2-3-4'}, 'station': {'station_name': 'Bergen St'}},
#  {'train': {'train_name': '2-3-4'},
#   'station': {'station_name': 'Grand Army Plaza'}},
#  {'train': {'train_name': '2-3-4'},
#   'station': {'station_name': 'Eastern Pkwy - Bklyn Museum'}},
#  {'train': {'train_name': '3-4'},
#   'station': {'station_name': 'Pennsylvania Ave'}},
#  {'train': {'train_name': '3-4'},
#   'station': {'station_name': 'Van Siclen Ave'}},
#  {'train': {'train_name': '3-4'},
#   'station': {'station_name': 'Crown Hts - Utica Ave'}},
#  {'train': {'train_name': '3-4'}, 'station': {'station_name': 'Kingston Ave'}},
#  {'train': {'train_name': '3-4'}, 'station': {'station_name': 'New Lots Ave'}},
#  {'train': {'train_name': '3-4'}, 'station': {'station_name': 'Junius St'}},
#  {'train': {'train_name': '3-4'}, 'station': {'station_name': 'Rockaway Ave'}},
#  {'train': {'train_name': '3-4'}, 'station': {'station_name': 'Saratoga Ave'}},
#  {'train': {'train_name': '3-4'},
#   'station': {'station_name': 'Sutter Ave - Rutland Road'}},
#  {'train': {'train_name': '3-4'}, 'station': {'station_name': 'Nostrand Ave'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '238th St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '145th St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '157th St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '103rd St'}},
#  {'train': {'train_name': '1'},
#   'station': {'station_name': 'Cathedral Pkwy (110th St)'}},
#  {'train': {'train_name': '1'},
#   'station': {'station_name': '116th St - Columbia University'}},
#  {'train': {'train_name': '1'},
#   'station': {'station_name': '137th St - City College'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '168th St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '181st St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '191st St'}},
#  {'train': {'train_name': '1'},
#   'station': {'station_name': 'Marble Hill - 225th St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '231st St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '215th St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '207th St'}},
#  {'train': {'train_name': '1'},
#   'station': {'station_name': 'Van Cortlandt Park - 242nd St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': 'Dyckman St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': '125th St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': 'South Ferry'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': 'Rector St'}},
#  {'train': {'train_name': '1'}, 'station': {'station_name': 'Cortlandt St'}},
#  {'train': {'train_name': 'A-B-C'},
#   'station': {'station_name': 'Cathedral Pkwy (110th St)'}},
#  {'train': {'train_name': 'A-B-C'}, 'station': {'station_name': '72nd St'}},
#  {'train': {'train_name': 'A-B-C'}, 'station': {'station_name': '96th St'}},
#  {'train': {'train_name': 'A-B-C'}, 'station': {'station_name': '103rd St'}},
#  {'train': {'train_name': 'A-B-C'}, 'station': {'station_name': '81st St'}},
#  {'train': {'train_name': 'A-B-C'}, 'station': {'station_name': '86th St'}},
#  {'train': {'train_name': 'A-B-C'}, 'station': {'station_name': '116th St'}},
#  {'train': {'train_name': 'A-B-C'}, 'station': {'station_name': '135th St'}},
#  {'train': {'train_name': 'A-C'},
#   'station': {'station_name': 'Kingston - Throop Aves'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': 'Ralph Ave'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': '168th St'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': 'Rockaway Ave'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': 'Nostrand Ave'}},
#  {'train': {'train_name': 'A-C'},
#   'station': {'station_name': 'Van Siclen Ave'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': 'Shepherd Ave'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': 'Utica Ave'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': 'Fulton St'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': 'Chambers St'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': 'Liberty Ave'}},
#  {'train': {'train_name': 'A-C'},
#   'station': {'station_name': 'Broadway Junction'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': '155th St'}},
#  {'train': {'train_name': 'A-C'},
#   'station': {'station_name': '163rd St - Amsterdam Av'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': 'Franklin Ave'}},
#  {'train': {'train_name': 'A-C'},
#   'station': {'station_name': 'Clinton - Washington Aves'}},
#  {'train': {'train_name': 'A-C'}, 'station': {'station_name': 'High St'}},
#  {'train': {'train_name': 'A-C'},
#   'station': {'station_name': 'Lafayette Ave'}},
#  {'train': {'train_name': 'E-M-R'}, 'station': {'station_name': '65th St'}},
#  {'train': {'train_name': 'E-M-R'}, 'station': {'station_name': '36th St'}},
#  {'train': {'train_name': 'E-M-R'},
#   'station': {'station_name': 'Elmhurst Ave'}},
#  {'train': {'train_name': 'E-M-R'}, 'station': {'station_name': '67th Ave'}},
#  {'train': {'train_name': 'E-M-R'},
#   'station': {'station_name': 'Grand Ave - Newtown'}},
#  {'train': {'train_name': 'E-M-R'},
#   'station': {'station_name': '63rd Dr - Rego Park'}},
#  {'train': {'train_name': 'E-M-R'},
#   'station': {'station_name': 'Woodhaven Blvd - Queens Mall'}},
#  {'train': {'train_name': 'E-M-R'}, 'station': {'station_name': '46th St'}},
#  {'train': {'train_name': 'E-M-R'},
#   'station': {'station_name': 'Northern Blvd'}},
#  {'train': {'train_name': 'E-M-R'},
#   'station': {'station_name': 'Steinway St'}},
#  {'train': {'train_name': 'E-M-R'}, 'station': {'station_name': 'Queens Plz'}},
#  {'train': {'train_name': 'J-M-Z'},
#   'station': {'station_name': 'Delancey St - Essex St'}},
#  {'train': {'train_name': 'J-M-Z'}, 'station': {'station_name': 'Marcy Ave'}},
#  {'train': {'train_name': 'J-M-Z'}, 'station': {'station_name': 'Myrtle Ave'}},
#  {'train': {'train_name': 'J-Z'},
#   'station': {'station_name': 'Van Siclen Ave'}},
#  {'train': {'train_name': 'J-Z'}, 'station': {'station_name': 'Norwood Ave'}},
#  {'train': {'train_name': 'J-Z'},
#   'station': {'station_name': '104th-102nd Sts'}},
#  {'train': {'train_name': 'J-Z'}, 'station': {'station_name': 'Chauncey St'}},
#  {'train': {'train_name': 'J-Z'},
#   'station': {'station_name': 'Woodhaven Blvd'}},
#  {'train': {'train_name': 'J-Z'}, 'station': {'station_name': '121st St'}},
#  {'train': {'train_name': 'J-Z'},
#   'station': {'station_name': 'Broadway Junction'}},
#  {'train': {'train_name': 'J-Z'}, 'station': {'station_name': 'Crescent St'}},
#  {'train': {'train_name': 'J-Z'},
#   'station': {'station_name': '75th St - Eldert Ln'}},
#  {'train': {'train_name': 'J-Z'}, 'station': {'station_name': 'Gates Ave'}},
#  {'train': {'train_name': 'J-Z'}, 'station': {'station_name': 'Fulton St'}},
#  {'train': {'train_name': 'J-Z'}, 'station': {'station_name': 'Chambers St'}},
#  {'train': {'train_name': 'J-Z'}, 'station': {'station_name': 'Canal St'}},
#  {'train': {'train_name': 'J-Z'}, 'station': {'station_name': 'Broad St'}},
#  {'train': {'train_name': 'J-Z'}, 'station': {'station_name': 'Bowery'}},
#  {'train': {'train_name': 'B-D-N-Q-R'},
#   'station': {'station_name': 'DeKalb Ave'}},
#  {'train': {'train_name': 'A-S'},
#   'station': {'station_name': 'Beach 105th St'}},
#  {'train': {'train_name': 'A-S'},
#   'station': {'station_name': 'Beach 90th St'}},
#  {'train': {'train_name': 'A-S'}, 'station': {'station_name': '111th St'}},
#  {'train': {'train_name': 'A-S'}, 'station': {'station_name': '104th St'}},
#  {'train': {'train_name': 'A-S'},
#   'station': {'station_name': 'Broad Channel'}},
#  {'train': {'train_name': 'A-S'},
#   'station': {'station_name': 'Rockaway Blvd'}},
#  {'train': {'train_name': 'A-S'},
#   'station': {'station_name': 'Beach 98th St'}},
#  {'train': {'train_name': 'A-S'},
#   'station': {'station_name': 'Rockaway Park - Beach 116 St'}},
#  {'train': {'train_name': 'A-S'}, 'station': {'station_name': 'Grant Ave'}},
#  {'train': {'train_name': 'A-S'},
#   'station': {'station_name': 'Ozone Park - Lefferts Blvd'}},
#  {'train': {'train_name': 'A-S'}, 'station': {'station_name': '88th St'}},
#  {'train': {'train_name': 'A-S'}, 'station': {'station_name': '80th St'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Freeman St'}},
#  {'train': {'train_name': '2-5'},
#   'station': {'station_name': 'Intervale Ave'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Pelham Pkwy'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Gun Hill Rd'}},
#  {'train': {'train_name': '2-5'},
#   'station': {'station_name': 'Nereid Ave (238 St)'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Simpson St'}},
#  {'train': {'train_name': '2-5'},
#   'station': {'station_name': 'Bronx Park East'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Winthrop St'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': '233rd St'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Beverly Rd'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Church Ave'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Newkirk Ave'}},
#  {'train': {'train_name': '2-5'},
#   'station': {'station_name': 'Brooklyn College - Flatbush Ave'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Sterling St'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': '225th St'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Jackson Ave'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Prospect Ave'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': '174th St'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Allerton Ave'}},
#  {'train': {'train_name': '2-5'},
#   'station': {'station_name': 'West Farms Sq - E Tremont Av'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': '219th St'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'Burke Ave'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'E 180th St'}},
#  {'train': {'train_name': '2-5'},
#   'station': {'station_name': '149th St - Grand Concourse'}},
#  {'train': {'train_name': '2-5'},
#   'station': {'station_name': '3rd Ave - 149th St'}},
#  {'train': {'train_name': '2-5'}, 'station': {'station_name': 'President St'}},
#  {'train': {'train_name': 'B-D'},
#   'station': {'station_name': '182nd-183rd Sts'}},
#  {'train': {'train_name': 'B-D'},
#   'station': {'station_name': '174th-175th Sts'}},
#  {'train': {'train_name': 'B-D'}, 'station': {'station_name': '167th St'}},
#  {'train': {'train_name': 'B-D'},
#   'station': {'station_name': 'Kingsbridge Rd'}},
#  {'train': {'train_name': 'B-D'}, 'station': {'station_name': 'Tremont Ave'}},
#  {'train': {'train_name': 'B-D'}, 'station': {'station_name': '170th St'}},
#  {'train': {'train_name': 'B-D'}, 'station': {'station_name': 'Fordham Rd'}},
#  {'train': {'train_name': 'B-D'},
#   'station': {'station_name': 'Bedford Park Blvd'}},
#  {'train': {'train_name': 'B-D'}, 'station': {'station_name': '155th St'}},
#  {'train': {'train_name': 'B-D'},
#   'station': {'station_name': '161st St - Yankee Stadium'}},
#  {'train': {'train_name': 'B-D'}, 'station': {'station_name': 'Grand St'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': 'Mets - Willets Point'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': 'Junction Blvd'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': 'Flushing - Main St'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': 'Woodside - 61st St'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': 'Court Sq'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': 'Hunters Point Ave'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': 'Vernon Blvd - Jackson Ave'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': 'Times Sq - 42nd St'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': 'Grand Central - 42nd St'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': '5th Ave - Bryant Pk'}},
#  {'train': {'train_name': '7-7 Express'},
#   'station': {'station_name': '34th St - Hudson Yards'}},
#  {'train': {'train_name': '6-6 Express'},
#   'station': {'station_name': 'Buhre Ave'}},
#  {'train': {'train_name': '6-6 Express'},
#   'station': {'station_name': '3rd Ave - 138th St'}},
#  {'train': {'train_name': '6-6 Express'},
#   'station': {'station_name': 'Castle Hill Ave'}},
#  {'train': {'train_name': '6-6 Express'},
#   'station': {'station_name': 'Zerega Ave'}},
#  {'train': {'train_name': '6-6 Express'},
#   'station': {'station_name': 'Hunts Point Ave'}},
#  {'train': {'train_name': '6-6 Express'},
#   'station': {'station_name': 'Middletown Rd'}},
#  {'train': {'train_name': '6-6 Express'},
#   'station': {'station_name': 'Pelham Bay Park'}},
#  {'train': {'train_name': '6-6 Express'},
#   'station': {'station_name': 'Westchester Sq - E Tremont Ave'}},
#  {'train': {'train_name': '6-6 Express'},
#   'station': {'station_name': 'Parkchester'}},
#  {'train': {'train_name': '4-5-6-6 Express'},
#   'station': {'station_name': 'Brooklyn Bridge - City Hall'}},
#  {'train': {'train_name': '4-5-6-6 Express'},
#   'station': {'station_name': 'Grand Central - 42nd St'}},
#  {'train': {'train_name': '4-5-6-6 Express'},
#   'station': {'station_name': 'Lexington Ave - 59th St'}},
#  {'train': {'train_name': '4-5-6-6 Express'},
#   'station': {'station_name': 'Union Sq - 14th St'}},
#  {'train': {'train_name': '4-5-6-6 Express'},
#   'station': {'station_name': '86th St'}},
#  {'train': {'train_name': '4-5-6-6 Express'},
#   'station': {'station_name': '125th St'}},
#  {'train': {'train_name': 'D-N-R'}, 'station': {'station_name': 'Union St'}},
#  {'train': {'train_name': 'D-N-R'},
#   'station': {'station_name': 'Prospect Ave'}},
#  {'train': {'train_name': 'D-N-R'},
#   'station': {'station_name': '4th Av - 9th St'}},
#  {'train': {'train_name': 'D-N-R'}, 'station': {'station_name': '36th St'}},
#  {'train': {'train_name': 'D-N-R'}, 'station': {'station_name': '25th St'}},
#  {'train': {'train_name': '2-3-4-5'},
#   'station': {'station_name': 'Franklin Ave'}},
#  {'train': {'train_name': '2-3-4-5'},
#   'station': {'station_name': "Atlantic Av - Barclay's Center"}},
#  {'train': {'train_name': '2-3-4-5'},
#   'station': {'station_name': 'Nevins St'}},
#  {'train': {'train_name': '4'},
#   'station': {'station_name': '149th St - Grand Concourse'}},
#  {'train': {'train_name': '4'},
#   'station': {'station_name': '161st St - Yankee Stadium'}},
#  {'train': {'train_name': '4'}, 'station': {'station_name': '176th St'}},
#  {'train': {'train_name': '4'}, 'station': {'station_name': 'Burnside Ave'}},
#  {'train': {'train_name': '4'}, 'station': {'station_name': 'Kingsbridge Rd'}},
#  {'train': {'train_name': '4'},
#   'station': {'station_name': 'Bedford Park Blvd - Lehman College'}},
#  {'train': {'train_name': '4'}, 'station': {'station_name': 'Mt Eden Ave'}},
#  {'train': {'train_name': '4'}, 'station': {'station_name': '170th St'}},
#  {'train': {'train_name': '4'}, 'station': {'station_name': 'Mosholu Pkwy'}},
#  {'train': {'train_name': '4'}, 'station': {'station_name': '167th St'}},
#  {'train': {'train_name': '4'}, 'station': {'station_name': '183rd St'}},
#  {'train': {'train_name': '4'}, 'station': {'station_name': 'Fordham Rd'}},
#  {'train': {'train_name': '4'}, 'station': {'station_name': 'Woodlawn'}},
#  {'train': {'train_name': '6'}, 'station': {'station_name': 'E 149th St'}},
#  {'train': {'train_name': '6'},
#   'station': {'station_name': 'Morrison Av - Soundview'}},
#  {'train': {'train_name': '6'}, 'station': {'station_name': 'Whitlock Ave'}},
#  {'train': {'train_name': '6'},
#   'station': {'station_name': 'St Lawrence Ave'}},
#  {'train': {'train_name': '6'}, 'station': {'station_name': 'Elder Ave'}},
#  {'train': {'train_name': '6'}, 'station': {'station_name': 'Longwood Ave'}},
#  {'train': {'train_name': '6'}, 'station': {'station_name': 'Cypress Ave'}},
#  {'train': {'train_name': '6'},
#   'station': {'station_name': "E 143rd St - St Mary's St"}},
#  {'train': {'train_name': '6'}, 'station': {'station_name': 'Brook Ave'}},
#  {'train': {'train_name': 'A'},
#   'station': {'station_name': 'Far Rockaway - Mott Ave'}},
#  {'train': {'train_name': 'A'},
#   'station': {'station_name': 'Aqueduct Racetrack'}},
#  {'train': {'train_name': 'A'}, 'station': {'station_name': '175th St'}},
#  {'train': {'train_name': 'A'}, 'station': {'station_name': 'Beach 44th St'}},
#  {'train': {'train_name': 'A'}, 'station': {'station_name': 'Beach 60th St'}},
#  {'train': {'train_name': 'A'}, 'station': {'station_name': 'Beach 36th St'}},
#  {'train': {'train_name': 'A'}, 'station': {'station_name': 'Beach 25th St'}},
#  {'train': {'train_name': 'A'}, 'station': {'station_name': 'Beach 67th St'}},
#  {'train': {'train_name': 'A'},
#   'station': {'station_name': 'Howard Beach - JFK Airport'}},
#  {'train': {'train_name': 'A'},
#   'station': {'station_name': 'Aqueduct - North Conduit Av'}},
#  {'train': {'train_name': 'A'},
#   'station': {'station_name': 'Inwood - 207th St'}},
#  {'train': {'train_name': 'A'}, 'station': {'station_name': '181st St'}},
#  {'train': {'train_name': 'A'}, 'station': {'station_name': '190th St'}},
#  {'train': {'train_name': 'A'}, 'station': {'station_name': 'Dyckman St'}},
#  {'train': {'train_name': 'B-D-F-M'},
#   'station': {'station_name': '42nd St - Bryant Pk'}},
#  {'train': {'train_name': 'B-D-F-M'},
#   'station': {'station_name': 'W 4th St - Washington Sq (Lower)'}},
#  {'train': {'train_name': 'B-D-F-M'},
#   'station': {'station_name': '47th-50th Sts - Rockefeller Ctr'}},
#  {'train': {'train_name': 'B-D-F-M'},
#   'station': {'station_name': 'Herald Sq - 34th St'}},
#  {'train': {'train_name': 'B-D-F-M'},
#   'station': {'station_name': 'Broadway - Lafayette St'}},
#  {'train': {'train_name': 'B-Q-S'},
#   'station': {'station_name': 'Prospect Park'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': '55th St'}},
#  {'train': {'train_name': 'D'},
#   'station': {'station_name': 'Norwood - 205th St'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': '50th St'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': '25th Ave'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': 'Bay Pky'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': '79th St'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': '71st St'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': '20th Ave'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': '18th Ave'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': '62nd St'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': 'Bay 50th St'}},
#  {'train': {'train_name': 'D'}, 'station': {'station_name': '9th Ave'}},
#  {'train': {'train_name': 'D'},
#   'station': {'station_name': 'Ft Hamilton Pkwy'}},
#  {'train': {'train_name': 'E'},
#   'station': {'station_name': 'Jamaica - Van Wyck'}},
#  {'train': {'train_name': 'E'},
#   'station': {'station_name': 'World Trade Center'}},
#  {'train': {'train_name': 'E-F'},
#   'station': {'station_name': 'Kew Gardens - Union Tpke'}},
#  {'train': {'train_name': 'E-F'}, 'station': {'station_name': '75th Ave'}},
#  {'train': {'train_name': 'E-F'},
#   'station': {'station_name': 'Briarwood - Van Wyck Blvd'}},
#  {'train': {'train_name': 'E-J-Z'},
#   'station': {'station_name': 'Sutphin Blvd - Archer Av'}},
#  {'train': {'train_name': 'E-J-Z'},
#   'station': {'station_name': 'Jamaica Ctr - Parsons / Archer'}},
#  {'train': {'train_name': 'E-M'},
#   'station': {'station_name': 'Court Sq - 23rd St'}},
#  {'train': {'train_name': 'E-M'},
#   'station': {'station_name': '5th Ave - 53rd St'}},
#  {'train': {'train_name': 'E-M'},
#   'station': {'station_name': 'Lexington Ave - 53rd St'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Ditmas Ave'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Parsons Blvd'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': '169th St'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Sutphin Blvd'}},
#  {'train': {'train_name': 'F'},
#   'station': {'station_name': 'Jamaica - 179th St'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': '18th Ave'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Ave U'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Kings Hwy'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Neptune Ave'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Ave X'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Ave P'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Ave N'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Bay Pky'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'Ave I'}},
#  {'train': {'train_name': 'F'},
#   'station': {'station_name': '21st St - Queensbridge'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': '57th St'}},
#  {'train': {'train_name': 'F'},
#   'station': {'station_name': 'Roosevelt Island - Main St'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'East Broadway'}},
#  {'train': {'train_name': 'F'},
#   'station': {'station_name': 'Delancey St - Essex St'}},
#  {'train': {'train_name': 'F'},
#   'station': {'station_name': 'Lower East Side - 2nd Ave'}},
#  {'train': {'train_name': 'F'}, 'station': {'station_name': 'York St'}},
#  {'train': {'train_name': 'G'}, 'station': {'station_name': 'Classon Ave'}},
#  {'train': {'train_name': 'G'}, 'station': {'station_name': 'Broadway'}},
#  {'train': {'train_name': 'G'},
#   'station': {'station_name': 'Bedford - Nostrand Aves'}},
#  {'train': {'train_name': 'G'}, 'station': {'station_name': 'Fulton St'}},
#  {'train': {'train_name': 'G'},
#   'station': {'station_name': 'Clinton - Washington Aves'}},
#  {'train': {'train_name': 'G'}, 'station': {'station_name': 'Nassau Ave'}},
#  {'train': {'train_name': 'G'}, 'station': {'station_name': 'Greenpoint Ave'}},
#  {'train': {'train_name': 'G'},
#   'station': {'station_name': 'Metropolitan Ave'}},
#  {'train': {'train_name': 'G'},
#   'station': {'station_name': 'Long Island City - Court Sq'}},
#  {'train': {'train_name': 'G'}, 'station': {'station_name': '21st St'}},
#  {'train': {'train_name': 'G'},
#   'station': {'station_name': 'Myrtle-Willoughby Aves'}},
#  {'train': {'train_name': 'G'}, 'station': {'station_name': 'Flushing Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Lorimer St'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Sutter Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Wilson Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': '1st Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Grand St'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Graham Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Bedford Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Montrose Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Atlantic Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Halsey St'}},
#  {'train': {'train_name': 'L'},
#   'station': {'station_name': 'Myrtle - Wyckoff Aves'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Livonia Ave'}},
#  {'train': {'train_name': 'L'},
#   'station': {'station_name': 'Canarsie - Rockaway Pkwy'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'E 105th St'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'New Lots Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'DeKalb Ave'}},
#  {'train': {'train_name': 'L'},
#   'station': {'station_name': 'Bushwick - Aberdeen'}},
#  {'train': {'train_name': 'L'},
#   'station': {'station_name': 'Broadway Junction'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Jefferson St'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': 'Morgan Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': '3rd Ave'}},
#  {'train': {'train_name': 'L'},
#   'station': {'station_name': 'Union Sq - 14th St'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': '6th Ave'}},
#  {'train': {'train_name': 'L'}, 'station': {'station_name': '8th Ave'}},
#  {'train': {'train_name': 'J'}, 'station': {'station_name': 'Halsey St'}},
#  {'train': {'train_name': 'J'},
#   'station': {'station_name': '85th St - Forest Pky'}},
#  {'train': {'train_name': 'J'}, 'station': {'station_name': '111th St'}},
#  {'train': {'train_name': 'J'}, 'station': {'station_name': 'Cleveland St'}},
#  {'train': {'train_name': 'J'}, 'station': {'station_name': 'Alabama Ave'}},
#  {'train': {'train_name': 'J'}, 'station': {'station_name': 'Cypress Hills'}},
#  {'train': {'train_name': 'J'}, 'station': {'station_name': 'Kosciuszko St'}},
#  {'train': {'train_name': 'J-M'}, 'station': {'station_name': 'Lorimer St'}},
#  {'train': {'train_name': 'J-M'}, 'station': {'station_name': 'Hewes St'}},
#  {'train': {'train_name': 'J-M'}, 'station': {'station_name': 'Flushing Ave'}},
#  {'train': {'train_name': 'N'}, 'station': {'station_name': '8th Ave'}},
#  {'train': {'train_name': 'N'},
#   'station': {'station_name': 'Ft Hamilton Pkwy'}},
#  {'train': {'train_name': 'N'}, 'station': {'station_name': '20th Ave'}},
#  {'train': {'train_name': 'N'}, 'station': {'station_name': '18th Ave'}},
#  {'train': {'train_name': 'N'},
#   'station': {'station_name': 'New Utrecht Ave'}},
#  {'train': {'train_name': 'N'}, 'station': {'station_name': 'Ave U'}},
#  {'train': {'train_name': 'N'}, 'station': {'station_name': 'Kings Hwy'}},
#  {'train': {'train_name': 'N'},
#   'station': {'station_name': 'Gravesend - 86th St'}},
#  {'train': {'train_name': 'N'}, 'station': {'station_name': 'Bay Pky'}},
#  {'train': {'train_name': 'N-W'}, 'station': {'station_name': '36th Ave'}},
#  {'train': {'train_name': 'N-W'}, 'station': {'station_name': 'Broadway'}},
#  {'train': {'train_name': 'N-W'}, 'station': {'station_name': '39th Ave'}},
#  {'train': {'train_name': 'N-W'}, 'station': {'station_name': 'Astoria Blvd'}},
#  {'train': {'train_name': 'N-W'},
#   'station': {'station_name': 'Astoria - Ditmars Blvd'}},
#  {'train': {'train_name': 'N-W'}, 'station': {'station_name': '30th Ave'}},
#  {'train': {'train_name': 'N-Q-R-W'},
#   'station': {'station_name': 'Times Sq - 42nd St'}},
#  {'train': {'train_name': 'N-Q-R-W'}, 'station': {'station_name': '28th St'}},
#  {'train': {'train_name': 'N-Q-R-W'},
#   'station': {'station_name': 'Herald Sq - 34th St'}},
#  {'train': {'train_name': 'N-Q-R-W'}, 'station': {'station_name': '49th St'}},
#  {'train': {'train_name': 'N-Q-R-W'}, 'station': {'station_name': '57th St'}},
#  {'train': {'train_name': 'N-Q-R-W'},
#   'station': {'station_name': 'Union Sq - 14th St'}},
#  {'train': {'train_name': 'N-Q-R-W'}, 'station': {'station_name': '23rd St'}},
#  {'train': {'train_name': 'N-Q-R-W'},
#   'station': {'station_name': 'Prince St'}},
#  {'train': {'train_name': 'N-Q-R-W'},
#   'station': {'station_name': '8th St - NYU'}},
#  {'train': {'train_name': 'S'},
#   'station': {'station_name': 'Grand Central - 42nd St'}},
#  {'train': {'train_name': 'S'}, 'station': {'station_name': 'Park Pl'}},
#  {'train': {'train_name': 'S'},
#   'station': {'station_name': 'Times Sq - 42nd St'}},
#  {'train': {'train_name': 'S'}, 'station': {'station_name': 'Botanic Garden'}},
#  {'train': {'train_name': 'S'},
#   'station': {'station_name': 'Franklin Ave - Fulton St'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': 'Ocean Pkwy'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': 'Beverly Rd'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': 'Parkside Ave'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': 'Ave U'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': 'Ave M'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': 'Ave J'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': 'Ave H'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': 'Neck Rd'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': 'Cortelyou Rd'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': '72nd St'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': '86th St'}},
#  {'train': {'train_name': 'Q'}, 'station': {'station_name': '96th St'}},
#  {'train': {'train_name': '7-7 Express-N-W'},
#   'station': {'station_name': 'Queensboro Plz'}},
#  {'train': {'train_name': 'F-G'},
#   'station': {'station_name': '15th St - Prospect Park'}},
#  {'train': {'train_name': 'F-G'}, 'station': {'station_name': '7th Ave'}},
#  {'train': {'train_name': 'F-G'},
#   'station': {'station_name': 'Ft Hamilton Pkwy'}},
#  {'train': {'train_name': 'F-G'}, 'station': {'station_name': 'Church Ave'}},
#  {'train': {'train_name': 'F-G'},
#   'station': {'station_name': '4th Av - 9th St'}},
#  {'train': {'train_name': 'F-G'},
#   'station': {'station_name': 'Smith - 9th Sts'}},
#  {'train': {'train_name': 'F-G'}, 'station': {'station_name': 'Bergen St'}},
#  {'train': {'train_name': 'F-G'}, 'station': {'station_name': 'Carroll St'}},
#  {'train': {'train_name': 'B-Q'}, 'station': {'station_name': 'Church Ave'}},
#  {'train': {'train_name': 'B-Q'}, 'station': {'station_name': 'Newkirk Ave'}},
#  {'train': {'train_name': 'B-Q'}, 'station': {'station_name': '7th Ave'}},
#  {'train': {'train_name': 'B-Q'},
#   'station': {'station_name': "Atlantic Av - Barclay's Center"}},
#  {'train': {'train_name': 'B-Q'},
#   'station': {'station_name': 'Brighton Beach'}},
#  {'train': {'train_name': 'B-Q'},
#   'station': {'station_name': 'Sheepshead Bay'}},
#  {'train': {'train_name': 'B-Q'}, 'station': {'station_name': 'Kings Hwy'}},
#  {'train': {'train_name': 'D-N-Q-R'},
#   'station': {'station_name': "Atlantic Av - Barclay's Center"}},
#  {'train': {'train_name': '4-5'}, 'station': {'station_name': 'Borough Hall'}},
#  {'train': {'train_name': '4-5'},
#   'station': {'station_name': '138th St - Grand Concourse'}},
#  {'train': {'train_name': '4-5'},
#   'station': {'station_name': 'Bowling Green'}},
#  {'train': {'train_name': '4-5'}, 'station': {'station_name': 'Wall St'}},
#  {'train': {'train_name': '4-5'}, 'station': {'station_name': 'Fulton St'}},
#  {'train': {'train_name': '5'}, 'station': {'station_name': 'Morris Park'}},
#  {'train': {'train_name': '5'}, 'station': {'station_name': 'Pelham Pkwy'}},
#  {'train': {'train_name': '5'}, 'station': {'station_name': 'Baychester Ave'}},
#  {'train': {'train_name': '5'},
#   'station': {'station_name': 'Eastchester - Dyre Ave'}},
#  {'train': {'train_name': '5'}, 'station': {'station_name': 'Gun Hill Rd'}},
#  {'train': {'train_name': '1-2-3'}, 'station': {'station_name': '96th St'}},
#  {'train': {'train_name': '1-2-3'}, 'station': {'station_name': '72nd St'}},
#  {'train': {'train_name': '1-2-3'},
#   'station': {'station_name': '34th St - Penn Station'}},
#  {'train': {'train_name': '1-2-3'},
#   'station': {'station_name': 'Times Sq - 42nd St'}},
#  {'train': {'train_name': '1-2-3'},
#   'station': {'station_name': 'Chambers St'}},
#  {'train': {'train_name': '1-2-3'}, 'station': {'station_name': '14th St'}},
#  {'train': {'train_name': '2-3'},
#   'station': {'station_name': 'Central Park North (110th St)'}},
#  {'train': {'train_name': '2-3'}, 'station': {'station_name': '125th St'}},
#  {'train': {'train_name': '2-3'}, 'station': {'station_name': '135th St'}},
#  {'train': {'train_name': '2-3'}, 'station': {'station_name': '116th St'}},
#  {'train': {'train_name': '2-3'}, 'station': {'station_name': 'Fulton St'}},
#  {'train': {'train_name': '2-3'}, 'station': {'station_name': 'Park Pl'}},
#  {'train': {'train_name': '2-3'}, 'station': {'station_name': 'Hoyt St'}},
#  {'train': {'train_name': '2-3'}, 'station': {'station_name': 'Borough Hall'}},
#  {'train': {'train_name': '2-3'}, 'station': {'station_name': 'Wall St'}},
#  {'train': {'train_name': '2-3'}, 'station': {'station_name': 'Clark St'}},
#  {'train': {'train_name': '3'}, 'station': {'station_name': '145th St'}},
#  {'train': {'train_name': '3'},
#   'station': {'station_name': 'Harlem - 148 St'}},
#  {'train': {'train_name': '7'},
#   'station': {'station_name': '103rd St - Corona Plaza'}},
#  {'train': {'train_name': '7'}, 'station': {'station_name': '111th St'}},
#  {'train': {'train_name': '7'}, 'station': {'station_name': '69th St'}},
#  {'train': {'train_name': '7'},
#   'station': {'station_name': '74th St - Broadway'}},
#  {'train': {'train_name': '7'}, 'station': {'station_name': '52nd St'}},
#  {'train': {'train_name': '7'}, 'station': {'station_name': '46th St'}},
#  {'train': {'train_name': '7'},
#   'station': {'station_name': '82nd St - Jackson Hts'}},
#  {'train': {'train_name': '7'},
#   'station': {'station_name': '90th St - Elmhurst Av'}},
#  {'train': {'train_name': '7'}, 'station': {'station_name': '33rd St'}},
#  {'train': {'train_name': '7'}, 'station': {'station_name': '40th St'}},
#  {'train': {'train_name': 'F-Q'},
#   'station': {'station_name': 'W 8th St - NY Aquarium'}},
#  {'train': {'train_name': 'F-Q'},
#   'station': {'station_name': 'Lexington Ave - 63rd St'}},
#  {'train': {'train_name': 'A-C-E'},
#   'station': {'station_name': 'W 4th St - Washington Sq (Upper)'}},
#  {'train': {'train_name': 'A-C-E'}, 'station': {'station_name': '50th St'}},
#  {'train': {'train_name': 'A-C-E'},
#   'station': {'station_name': '42nd St - Port Authority Bus Term'}},
#  {'train': {'train_name': 'A-C-E'}, 'station': {'station_name': 'Spring St'}},
#  {'train': {'train_name': 'A-C-E'},
#   'station': {'station_name': 'Canal St - Holland Tunnel'}},
#  {'train': {'train_name': 'A-C-E'}, 'station': {'station_name': '23rd St'}},
#  {'train': {'train_name': 'A-C-E'},
#   'station': {'station_name': '34th St - Penn Station'}},
#  {'train': {'train_name': 'A-C-E'}, 'station': {'station_name': '14th St'}},
#  {'train': {'train_name': 'M'},
#   'station': {'station_name': 'Myrtle - Wyckoff Aves'}},
#  {'train': {'train_name': 'M'}, 'station': {'station_name': 'Seneca Ave'}},
#  {'train': {'train_name': 'M'}, 'station': {'station_name': 'Central Ave'}},
#  {'train': {'train_name': 'M'},
#   'station': {'station_name': 'Knickerbocker Ave'}},
#  {'train': {'train_name': 'M'}, 'station': {'station_name': 'Fresh Pond Rd'}},
#  {'train': {'train_name': 'M'},
#   'station': {'station_name': 'Middle Village - Metropolitan Ave'}},
#  {'train': {'train_name': 'M'}, 'station': {'station_name': 'Forest Ave'}},
#  {'train': {'train_name': 'E-F-M-R'},
#   'station': {'station_name': 'Forest Hills - 71st Av'}},
#  {'train': {'train_name': 'E-F-M-R'},
#   'station': {'station_name': 'Jackson Hts - Roosevelt Av'}},
#  {'train': {'train_name': '2'},
#   'station': {'station_name': 'Wakefield - 241st St'}},
#  {'train': {'train_name': 'A-B-C-D'}, 'station': {'station_name': '145th St'}},
#  {'train': {'train_name': 'A-B-C-D'},
#   'station': {'station_name': '59th St - Columbus Circle'}},
#  {'train': {'train_name': 'A-B-C-D'}, 'station': {'station_name': '125th St'}},
#  {'train': {'train_name': 'R'}, 'station': {'station_name': '77th St'}},
#  {'train': {'train_name': 'R'}, 'station': {'station_name': 'Bay Ridge Ave'}},
#  {'train': {'train_name': 'R'},
#   'station': {'station_name': 'Bay Ridge - 95th St'}},
#  {'train': {'train_name': 'R'}, 'station': {'station_name': '86th St'}},
#  {'train': {'train_name': 'B-D-E'}, 'station': {'station_name': '7th Ave'}},
#  {'train': {'train_name': 'N-R-W'},
#   'station': {'station_name': '5th Ave - 59th St'}},
#  {'train': {'train_name': 'N-R-W'},
#   'station': {'station_name': 'Lexington Ave - 59th St'}},
#  {'train': {'train_name': 'F-M'}, 'station': {'station_name': '23rd St'}},
#  {'train': {'train_name': 'F-M'}, 'station': {'station_name': '14th St'}},
#  {'train': {'train_name': 'A-C-G'},
#   'station': {'station_name': 'Hoyt - Schermerhorn Sts'}},
#  {'train': {'train_name': 'A-C-F'},
#   'station': {'station_name': 'Jay St - MetroTech'}},
#  {'train': {'train_name': 'N-R'},
#   'station': {'station_name': 'Jay St - MetroTech'}},
#  {'train': {'train_name': 'N-R'}, 'station': {'station_name': 'Court St'}},
#  {'train': {'train_name': 'N-R'}, 'station': {'station_name': '59th St'}},
#  {'train': {'train_name': 'N-R'}, 'station': {'station_name': '45th St'}},
#  {'train': {'train_name': 'N-R'}, 'station': {'station_name': '53rd St'}},
#  {'train': {'train_name': 'R-W'}, 'station': {'station_name': 'City Hall'}},
#  {'train': {'train_name': 'R-W'}, 'station': {'station_name': 'Canal St'}},
#  {'train': {'train_name': 'R-W'}, 'station': {'station_name': 'Whitehall St'}},
#  {'train': {'train_name': 'R-W'}, 'station': {'station_name': 'Rector St'}},
#  {'train': {'train_name': 'R-W'}, 'station': {'station_name': 'Cortlandt St'}},
#  {'train': {'train_name': 'N-Q'}, 'station': {'station_name': 'Canal St'}},
#  {'train': {'train_name': 'A-C-S'}, 'station': {'station_name': 'Euclid Ave'}},
#  {'train': {'train_name': 'D-F-N-Q'},
#   'station': {'station_name': 'Coney Island - Stillwell Av'}}]

# %%
df1=pd.DataFrame(data)

# %%
df1
# Out:
#                                train  \
# 0    {'train_name': '4-6-6 Express'}
# 1    {'train_name': '4-6-6 Express'}
# 2    {'train_name': '4-6-6 Express'}
# 3    {'train_name': '4-6-6 Express'}
# 4    {'train_name': '4-6-6 Express'}
# ..                               ...
# 468            {'train_name': 'R-W'}
# 469            {'train_name': 'R-W'}
# 470            {'train_name': 'N-Q'}
# 471          {'train_name': 'A-C-S'}
# 472        {'train_name': 'D-F-N-Q'}
#
#                                              station
# 0                       {'station_name': 'Astor Pl'}
# 1                       {'station_name': 'Canal St'}
# 2                        {'station_name': '33rd St'}
# 3                        {'station_name': '96th St'}
# 4                        {'station_name': '77th St'}
# ..                                               ...
# 468                    {'station_name': 'Rector St'}
# 469                 {'station_name': 'Cortlandt St'}
# 470                     {'station_name': 'Canal St'}
# 471                   {'station_name': 'Euclid Ave'}
# 472  {'station_name': 'Coney Island - Stillwell Av'}
#
# [473 rows x 2 columns]

# %%
df1["train"][0]["train_name"]
# Out:
# '4-6-6 Express'

# %%
for i in range(len(df1['train'])):
    df1['train'][i]=df1["train"][i]["train_name"]

# %%
df1
# Out:
#              train                                          station
# 0    4-6-6 Express                     {'station_name': 'Astor Pl'}
# 1    4-6-6 Express                     {'station_name': 'Canal St'}
# 2    4-6-6 Express                      {'station_name': '33rd St'}
# 3    4-6-6 Express                      {'station_name': '96th St'}
# 4    4-6-6 Express                      {'station_name': '77th St'}
# ..             ...                                              ...
# 468            R-W                    {'station_name': 'Rector St'}
# 469            R-W                 {'station_name': 'Cortlandt St'}
# 470            N-Q                     {'station_name': 'Canal St'}
# 471          A-C-S                   {'station_name': 'Euclid Ave'}
# 472        D-F-N-Q  {'station_name': 'Coney Island - Stillwell Av'}
#
# [473 rows x 2 columns]

# %%
#cleaning data
for i in range(len(df1['station'])):
    df1['station'][i]=df1["station"][i]['station_name']

# %%
df1
# Out:
#              train                      station
# 0    4-6-6 Express                     Astor Pl
# 1    4-6-6 Express                     Canal St
# 2    4-6-6 Express                      33rd St
# 3    4-6-6 Express                      96th St
# 4    4-6-6 Express                      77th St
# ..             ...                          ...
# 468            R-W                    Rector St
# 469            R-W                 Cortlandt St
# 470            N-Q                     Canal St
# 471          A-C-S                   Euclid Ave
# 472        D-F-N-Q  Coney Island - Stillwell Av
#
# [473 rows x 2 columns]

# %%
# train names as per the connectivity count
train__names=df1['train'].value_counts().sort_values(ascending=False)

# %%
train__names
# Out:
# 2-5                26
# L                  24
# F                  21
# 1                  20
# A-C                18
#                    ..
# 7-7 Express-N-W     1
# N-Q                 1
# 2                   1
# B-D-E               1
# B-Q-S               1
# Name: train, Length: 66, dtype: int64

# %%
# station name as per the connectivity counts
station__names=df1['station'].value_counts().sort_values(ascending=False)

# %%
station__names
# Out:
# Canal St                             5
# 23rd St                              5
# Fulton St                            5
# 86th St                              5
# 96th St                              4
#                                     ..
# Ave M                                1
# 34th St - Hudson Yards               1
# 225th St                             1
# Brook Ave                            1
# Middle Village - Metropolitan Ave    1
# Name: station, Length: 355, dtype: int64

# %%
# query to count the total
q3='''
match(a:TRAIN)-[:GOES_TO]->(b:STATION)
with a AS Train_Name,collect(b) as Station,count(*) as count
return Train_Name,Station,count
'''

# %%
results_a=session.run(q3)

# %%
data_new=results_a.data()

# %%
df2=pd.DataFrame(data_new)

# %%
df2
# Out:
#                          Train_Name  \
# 0   {'train_name': '4-6-6 Express'}
# 1             {'train_name': '1-2'}
# 2           {'train_name': '2-3-4'}
# 3             {'train_name': '3-4'}
# 4               {'train_name': '1'}
# ..                              ...
# 61            {'train_name': 'N-R'}
# 62            {'train_name': 'R-W'}
# 63            {'train_name': 'N-Q'}
# 64          {'train_name': 'A-C-S'}
# 65        {'train_name': 'D-F-N-Q'}
#
#                                               Station  count
# 0   [{'station_name': 'Spring St'}, {'station_name...     14
# 1   [{'station_name': 'Franklin St'}, {'station_na...     12
# 2   [{'station_name': 'Eastern Pkwy - Bklyn Museum...      3
# 3   [{'station_name': 'Nostrand Ave'}, {'station_n...     10
# 4   [{'station_name': 'Cortlandt St'}, {'station_n...     20
# ..                                                ...    ...
# 61  [{'station_name': '53rd St'}, {'station_name':...      5
# 62  [{'station_name': 'Cortlandt St'}, {'station_n...      5
# 63                     [{'station_name': 'Canal St'}]      1
# 64                   [{'station_name': 'Euclid Ave'}]      1
# 65  [{'station_name': 'Coney Island - Stillwell Av'}]      1
#
# [66 rows x 3 columns]

# %%
for i in range(len(df2['Train_Name'])):
    df2['Train_Name'][i]=df2["Train_Name"][i]["train_name"]
# Out:
# <ipython-input-106-76b608f557df>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Train_Name'][i]=df2["Train_Name"][i]["train_name"]

# %%
df2
# Out:
#        Train_Name                                            Station  count
# 0   4-6-6 Express  [{'station_name': 'Spring St'}, {'station_name...     14
# 1             1-2  [{'station_name': 'Franklin St'}, {'station_na...     12
# 2           2-3-4  [{'station_name': 'Eastern Pkwy - Bklyn Museum...      3
# 3             3-4  [{'station_name': 'Nostrand Ave'}, {'station_n...     10
# 4               1  [{'station_name': 'Cortlandt St'}, {'station_n...     20
# ..            ...                                                ...    ...
# 61            N-R  [{'station_name': '53rd St'}, {'station_name':...      5
# 62            R-W  [{'station_name': 'Cortlandt St'}, {'station_n...      5
# 63            N-Q                     [{'station_name': 'Canal St'}]      1
# 64          A-C-S                   [{'station_name': 'Euclid Ave'}]      1
# 65        D-F-N-Q  [{'station_name': 'Coney Island - Stillwell Av'}]      1
#
# [66 rows x 3 columns]

# %%
len(df2["Train_Name"].unique())
# Out:
# 66

# %%
df2
# Out:
#   Train_Name                                            Station  count
# 0       None  [{'station_name': 'Astor Pl'}, {'station_name'...    473

# %%
df2.to_csv("train_vs_station.csv",index=False)
